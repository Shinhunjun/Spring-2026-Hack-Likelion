# %%
import pandas as pd
df = pd.read_csv('../../data/ICD_codes.csv')
df.head()
# Out:
#     Code                                        Description CodeType  \
# 0  33183               Mild cognitive impairment, so stated     icd9
# 1  G3184  Mild cognitive impairment of uncertain or unkn...    icd10
# 2   3310                                Alzheimer's disease     icd9
# 3   G300               Alzheimer's disease with early onset    icd10
# 4   G301                Alzheimer's disease with late onset    icd10
#
#              Diagnosis
# 0                  MCI
# 1                  MCI
# 2  Alzheimer's disease
# 3  Alzheimer's disease
# 4  Alzheimer's disease

# %%
df['Diagnosis'].value_counts()
# Out:
# Diagnosis
# Dementia               108
# Alzheimer's disease      5
# MCI                      2
# Name: count, dtype: int64
